# %%
import os

if os.getcwd().endswith("notebooks"):
    os.chdir("..")
print(os.getcwd())
# Out:
# /Users/cmcoutosilva/Projects/github/nl2sql-agent

# %%
from datetime import datetime
from typing import Annotated, Any, Literal

import pandas as pd
from langchain.chat_models import init_chat_model
from langchain_core.messages import AIMessage, HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.graph import END, START, StateGraph
from langgraph.graph.message import BaseMessage, add_messages
from langgraph.types import Command, interrupt
from loguru import logger
from pydantic import BaseModel

from nl2sql.agents.utils import (
    execute_sql_query,
    format_answer,
    format_query_results_for_llm,
    get_chat_history,
    validate_sql_syntax,
)
from nl2sql.config import UNSAFE_SQL_KEYWORDS, load_chat_prompt_template
from nl2sql.database.postgresql import PostgreSQLConnector
from nl2sql.knowledge_base.data_dictionary import DataDictionary
from nl2sql.knowledge_base.sql_examples import SQLExample
from nl2sql.knowledge_base.vector_store import VectorStore

# %%
# ===============================
# Vector Store
# ===============================

db_connector = PostgreSQLConnector(config_path="configs/database.yml")
vector_store = VectorStore(db_connector)

# %%
# ===============================
# Session-based Memory
# ===============================

# In-memory session saver
memory = InMemorySaver()

# Thread ID used to identify the session
session_id = "test_" + datetime.now().isoformat()
thread_config = {"configurable": {"thread_id": session_id}}

# ===============================
# State
# ===============================


class State(BaseModel):
    """State for the NL2SQL agent."""

    messages: Annotated[list[BaseMessage], add_messages]
    user_query: str | None = None
    user_intent: Literal["sql", "chat"] | None = None
    sql_query: str | None = None
    sql_explanation: str | None = None
    sql_execution_result: dict[str, Any] | None = None
    sql_execution_analysis: str | None = None
    sql_safety_status: Literal["safe", "unsafe"] | None = None
    sql_syntax_status: Literal["valid", "invalid"] | None = None
    user_feedback_status: Literal["approved", "rejected"] | None = None
    sql_execution_status: Literal["success", "failure"] | None = None


# ===============================
# Prompts & Knowledge Base
# ===============================

intent_classifier_prompt = load_chat_prompt_template(target_prompt="intent_classifier")
sql_generator_prompt = load_chat_prompt_template(target_prompt="sql_generator")

# Load knowledge base components
data_dictionary = DataDictionary.load()
sql_examples = SQLExample.from_yaml("knowledge/sql_examples.yml")

# ===============================
# Knowledge Base
# ===============================

# Load data dictionary and SQL examples
data_dictionary = DataDictionary.load()
sql_examples = SQLExample.from_yaml("knowledge/sql_examples.yml")

# ===============================
# Agent Nodes
# ===============================


def intent_classifier(state: State) -> dict:
    """Determine if user wants chat or SQL functionality."""
    logger.info("🔄 [Node] Intent Classifier")

    # Retrieve chat history
    chat_history = get_chat_history(state.messages[:-1])
    user_query = state.messages[-1].content
    logger.debug(f"Chat history:\n{chat_history}")
    logger.debug(f"Last message: {user_query}")

    # Classify user intent using LLM
    llm = init_chat_model(model="gpt-4.1-mini", model_provider="openai", temperature=0)
    router_llm_chain = intent_classifier_prompt | llm

    response = router_llm_chain.invoke(
        {"user_message": user_query, "chat_history": chat_history}
    )

    detected_user_intent = response.content.strip().lower()
    logger.debug(f"Detected user intent: {detected_user_intent}")

    # Default to chat if the intent is not chat or sql
    if detected_user_intent not in ["chat", "sql"]:
        logger.warning(
            "⚠️ LLM Router returned unexpected classification: "
            f"'{detected_user_intent}'. Defaulting to chat."
        )
        return {"user_intent": "chat"}

    return {"user_intent": detected_user_intent, "user_query": user_query}


def chat_agent(state: State, vector_store: VectorStore) -> dict:
    """Chat agent node."""
    logger.info("🔄 [Node] Chat Agent")
    response = "Hello, how can I help you today?"
    logger.debug(f"✅ Chat Agent response: {response[:50]}...")
    return {"messages": AIMessage(content=response)}


def sql_generator(state: State, vector_store: VectorStore) -> dict:
    """Generate SQL query from natural language using LLM and context."""
    logger.info("🔄 [Node] SQL Generator")
    logger.debug(f"User question: {state.user_query}")

    # Get chat history for context
    chat_history = get_chat_history(state.messages[:-1])
    logger.debug(f"Chat history length: {len(chat_history)}")

    # Format schema context from data dictionary
    schema_context = data_dictionary.format_context()

    # Format SQL examples for few-shot learning
    retrieved_docs = vector_store.vectorstore.similarity_search(
        state.user_query, k=4, filter={"type": "example"}
    )
    logger.debug(f"Retrieved {len(retrieved_docs)} docs")
    sql_examples_context = "\n\n".join([doc.page_content for doc in retrieved_docs])

    # Initialize LLM
    llm = init_chat_model(
        model="gpt-4.1-mini", model_provider="openai", temperature=0
    ).with_structured_output(method="json_mode")  # returns dict directly

    # Create SQL generation chain
    llm_chain = sql_generator_prompt | llm

    # Generate SQL query
    response = llm_chain.invoke(
        {
            "user_query": state.user_query,
            "chat_history": chat_history,
            "schema_context": schema_context,
            "sql_examples": sql_examples_context,
        }
    )

    # TODO: Add key validation for the response

    return response


def sql_safety_validator(state: State) -> dict:
    """Validate if the SQL query is safe."""
    import re

    logger.info("🔄 [Node] SQL Safety Validator")

    found_unsafe_keywords = []
    for keyword in UNSAFE_SQL_KEYWORDS:
        if re.search(rf"\b{keyword}\b", state.sql_query):
            found_unsafe_keywords.append(keyword.upper())

    if found_unsafe_keywords:
        logger.error(f"❌ SQL contains unsafe keywords: {found_unsafe_keywords}")
        ai_message = AIMessage(
            content=f"❌ SQL contains unsafe keywords: {found_unsafe_keywords}"
        )
        return {"messages": [ai_message], "sql_safety_status": "unsafe"}
    else:
        logger.debug("✅ SQL is safe")
        return {"sql_safety_status": "safe"}


def sql_syntax_validator(state: State, db_connector: PostgreSQLConnector) -> dict:
    """Validate SQL syntax and attempt to fix errors using LLM."""
    logger.info("🔄 [Node] SQL Syntax Validator")

    max_retries = 3
    current_query = state.sql_query

    for attempt in range(max_retries):
        # Validate current query
        validation_result = validate_sql_syntax(current_query, db_connector)

        # If the query is valid, return success
        if validation_result["valid_syntax"]:
            logger.debug("✅ Syntax Validator: SQL syntax is valid.")
            return {
                "sql_syntax_status": "valid",
                "sql_query": current_query,
            }

        # Log the error and the current query for debugging
        logger.debug(f"Invalid syntax → Entering Fix Attempt #{attempt + 1}...")
        logger.debug(f"Current query: {current_query}")
        logger.debug(f"Error: {validation_result['error']}")

        # Use LLM to fix the error
        sql_syntax_fixer_prompt = load_chat_prompt_template(
            target_prompt="sql_syntax_fixer"
        )
        llm = init_chat_model(model="gpt-4.1", model_provider="openai", temperature=0)
        llm_chain = sql_syntax_fixer_prompt | llm
        fixed_query = llm_chain.invoke(
            {
                "query": current_query,
                "error": validation_result["error"],
            }
        ).content
        current_query = fixed_query

    logger.warning(
        f"⚠️ Syntax Validator: Failed to fix SQL syntax after {max_retries} attempts."
    )
    return {
        "sql_syntax_status": False,
        "messages": [
            AIMessage(
                content=(
                    f"❌ I couldn't generate valid SQL syntax. Error: "
                    f"{validation_result['error']}"
                )
            )
        ],
    }


def human_feedback(state: State) -> dict:
    """Ask for human confirmation and pause for input."""
    logger.info("🔄 [Node] Human Feedback")

    # Format the answer for the user
    formatted_answer = format_answer(state)
    formatted_answer += "Should I execute this query? Answer with 'yes' or 'no'."

    # Create the AI message
    ai_message = AIMessage(content=formatted_answer)

    # Mark that we're waiting for confirmation (Slack integration will detect this)
    human_reply = (
        interrupt(
            {
                "messages": ai_message,
                "waiting_for_confirmation": True,
            }
        )
        .content.strip()
        .lower()
    )

    user_feedback_status = "approved" if "y" in human_reply else "rejected"

    if user_feedback_status == "approved":
        logger.debug(f"✅ Human feedback: {user_feedback_status}")
    else:
        logger.debug(f"❌ Human feedback: {user_feedback_status}")

    return {
        "messages": [ai_message, human_reply],
        "user_feedback_status": user_feedback_status,
    }


def sql_executor(state: State, db_connector: PostgreSQLConnector) -> dict:
    """Execute the SQL query."""
    logger.info("🔄 [Node] SQL Executor")

    # Execute the SQL query
    sql_execution_result = execute_sql_query(state.sql_query, db_connector)
    sql_execution_status = "success" if sql_execution_result["success"] else "failure"

    if sql_execution_status:
        logger.debug(f"✅ SQL execution status: {sql_execution_status}")
        logger.debug(f"✅ SQL result: {sql_execution_result['data'][:50]}...")
    else:
        logger.debug(f"❌ SQL execution status: {sql_execution_status}")
        logger.debug(f"❌ SQL result: {sql_execution_result['error']}")

    return {
        "sql_execution_status": sql_execution_status,
        "sql_execution_result": sql_execution_result,
    }


def sql_result_analyzer(state: State) -> dict:
    """Analyse the SQL result using LLM."""
    logger.info("🔄 [Node] SQL Result Analyser")

    # Reconstruct execution result with DataFrame for formatting
    execution_result_for_formatting = state.sql_execution_result.copy()
    if execution_result_for_formatting["data"] is not None:
        # Convert back to DataFrame for the formatting function
        execution_result_for_formatting["data"] = pd.DataFrame(
            execution_result_for_formatting["data"]
        )

    # Format results for LLM interpretation
    formatted_results = format_query_results_for_llm(execution_result_for_formatting)

    # Load the result interpretation prompt
    result_analyzer_prompt = load_chat_prompt_template(target_prompt="result_analyzer")

    # Initialize LLM
    llm = init_chat_model(model="gpt-4.1", model_provider="openai", temperature=0.1)

    # Create the interpretation chain
    llm_chain = result_analyzer_prompt | llm

    # Generate interpretation
    response = llm_chain.invoke(
        {
            "user_query": state.user_query,
            "sql_query": state.sql_query,
            "query_results": formatted_results,
        }
    )

    analyzed_result = response.content
    logger.info("✅ Results analyzed successfully")

    # Create final response message
    final_message = AIMessage(content=analyzed_result)

    return {
        "messages": [final_message],
        "sql_execution_analysis": analyzed_result,
    }


# ===============================
# Node Rounters
# ===============================


def route_intent(state: State) -> Literal["sql", "chat"]:
    """Route intent to either SQL or Chat agent."""
    logger.debug(f"→ Routing to {state.user_intent}")
    return state.user_intent


def check_sql_generation(state: State) -> Literal["success", "failure"]:
    """Check if the SQL query is valid."""
    if state.sql_query and state.sql_query.strip():
        logger.debug("→ Routing to success")
        return "success"
    else:
        logger.debug("→ Routing to failure")
        return "failure"


def check_sql_safety(state: State) -> Literal["safe", "unsafe"]:
    """Check if the SQL query is safe."""
    logger.debug(f"→ Routing to {state.sql_safety_status}")
    return "safe" if state.sql_safety_status == "safe" else "unsafe"


def check_sql_syntax(state: State) -> Literal["valid", "invalid"]:
    """Check if the SQL query is valid."""
    logger.debug(f"→ Routing to {state.sql_syntax_status}")
    return "valid" if state.sql_syntax_status == "valid" else "invalid"


def check_human_feedback(state: State) -> Literal["approved", "rejected"]:
    """Check if user approved the SQL query."""
    logger.debug(f"→ Routing to {state.user_feedback_status}")
    return "approved" if state.user_feedback_status == "approved" else "rejected"


def check_sql_execution(state: State) -> Literal["success", "failure"]:
    """Check if the SQL query was executed successfully."""
    logger.debug(f"→ Routing to {state.sql_execution_status}")
    return "success" if state.sql_execution_status == "success" else "failure"


# ===============================
# Graph
# ===============================

# State Workflow
workflow = StateGraph(State)

# Add nodes
workflow.add_node("intent_classifier", intent_classifier)
workflow.add_node("chat_agent", chat_agent)
workflow.add_node("sql_generator", sql_generator)
workflow.add_node("sql_safety_validator", sql_safety_validator)
workflow.add_node("sql_syntax_validator", sql_syntax_validator)
workflow.add_node("human_feedback", human_feedback)
workflow.add_node("sql_executor", sql_executor)
workflow.add_node("sql_result_analyzer", sql_result_analyzer)

# Add Edges
workflow.add_edge(START, "intent_classifier")

workflow.add_conditional_edges(
    "intent_classifier",
    route_intent,
    {
        "sql": "sql_generator",
        "chat": "chat_agent",
    },
)

workflow.add_conditional_edges(
    "sql_generator",
    check_sql_generation,
    {
        "success": "sql_safety_validator",
        "failure": END,
    },
)

workflow.add_conditional_edges(
    "sql_safety_validator",
    check_sql_safety,
    {
        "safe": "sql_syntax_validator",
        "unsafe": END,
    },
)

workflow.add_conditional_edges(
    "sql_syntax_validator",
    check_sql_syntax,
    {
        "valid": "human_feedback",
        "invalid": END,
    },
)

workflow.add_conditional_edges(
    "human_feedback",
    check_human_feedback,
    {
        "approved": "sql_executor",
        "rejected": END,
    },
)

workflow.add_conditional_edges(
    "sql_executor",
    check_sql_execution,
    {
        "success": "sql_result_analyzer",
        "failure": END,
    },
)

workflow.add_edge("sql_result_analyzer", END)
workflow.add_edge("chat_agent", END)

# Compile Graph
graph = workflow.compile(checkpointer=memory)

# # Display Graph
# display(graph)

# %%
# Simulate SQL agent interaction

state = State(
    messages=[
        HumanMessage(content="What are the most popular product categories?"),
        # HumanMessage(content="Hello!"),
    ],
)

graph.invoke(state, config=thread_config)
# Out:
# 2025-07-08 05:10:45.376 | INFO     | __main__:intent_classifier:59 - 🔄 [Node] Intent Classifier
# 2025-07-08 05:10:45.376 | DEBUG    | __main__:intent_classifier:64 - Chat history:
#
# 2025-07-08 05:10:45.377 | DEBUG    | __main__:intent_classifier:65 - Last message: What are the most popular product categories?
# 2025-07-08 05:10:45.733 | DEBUG    | __main__:intent_classifier:76 - Detected user intent: sql
# 2025-07-08 05:10:45.734 | DEBUG    | __main__:route_intent:325 - → Routing to sql
# 2025-07-08 05:10:45.735 | INFO     | __main__:sql_generator:99 - 🔄 [Node] SQL Generator
# 2025-07-08 05:10:45.736 | DEBUG    | __main__:sql_generator:100 - User question: What are the most popular product categories?
# 2025-07-08 05:10:45.736 | DEBUG    | __main__:sql_generator:104 - Chat history length: 0
# 2025-07-08 05:10:46.016 | DEBUG    | __main__:sql_generator:113 - Retrieved 4 docs
# 2025-07-08 05:10:47.923 | DEBUG    | __main__:check_sql_generation:332 - → Routing to success
# 2025-07-08 05:10:47.924 | INFO     | __main__:sql_safety_validator:143 - 🔄 [Node] SQL Safety Validator
# 2025-07-08 05:10:47.925 | DEBUG    | __main__:sql_safety_validator:157 - ✅ SQL is safe
# 2025-07-08 05:10:47.926 | DEBUG    | __main__:check_sql_safety:341 - → Routing to safe
# 2025-07-08 05:10:47.926 | INFO     | __main__:sql_syntax_validator:163 - 🔄 [Node] SQL Syntax Validator
# 2025-07-08 05:10:47.931 | DEBUG    | __main__:sql_syntax_validator:174 - ✅ Syntax Validator: SQL syntax is valid.
# 2025-07-08 05:10:47.931 | DEBUG    | __main__:check_sql_syntax:347 - → Routing to valid
# 2025-07-08 05:10:47.932 | INFO     | __main__:human_feedback:217 - 🔄 [Node] Human Feedback
# {'messages': [HumanMessage(content='What are the most popular product categories?', additional_kwargs={}, response_metadata={}, id='03413633-c13c-4418-9a01-82fc7b5e370f')],
#  'user_query': 'What are the most popular product categories?',
#  'user_intent': 'sql',
#  'sql_query': 'SELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ecommerce"."products" p ON oi."product_id" = p."product_id" GROUP BY p."product_category_name" ORDER BY order_count DESC;',
#  'sql_explanation': 'This query counts the number of order items for each product category to determine the most popular product categories, ordering the results by the count in descending order.',
#  'sql_safety_status': 'safe',
#  'sql_syntax_status': 'valid',
#  '__interrupt__': [Interrupt(value={'messages': AIMessage(content='**SQL:**\n```sql\nSELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ecommerce"."products" p ON oi."product_id" = p."product_id" GROUP BY p."product_category_name" ORDER BY order_count DESC;\n```\n\n**Explanation:**\nThis query counts the number of order items for each product category to determine the most popular product categories, ordering the results by the count in descending order.\nShould I execute this query? Answer with \'yes\' or \'no\'.', additional_kwargs={}, response_metadata={}), 'waiting_for_confirmation': True}, resumable=True, ns=['human_feedback:3b2f7923-01e8-95a3-84fa-d7c2494e5c68'])]}

# %%
graph.invoke(Command(resume=HumanMessage(content="yes")), thread_config)
# Out:
# 2025-07-08 05:10:47.943 | INFO     | __main__:human_feedback:217 - 🔄 [Node] Human Feedback
# 2025-07-08 05:10:47.944 | DEBUG    | __main__:human_feedback:241 - ✅ Human feedback: approved
# 2025-07-08 05:10:47.944 | DEBUG    | __main__:check_human_feedback:353 - → Routing to approved
# 2025-07-08 05:10:47.945 | INFO     | __main__:sql_executor:253 - 🔄 [Node] SQL Executor
# 2025-07-08 05:10:47.945 | DEBUG    | nl2sql.agents.utils:execute_sql_query:81 - 🔄 Executing SQL query: SELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ec...
# 2025-07-08 05:10:47.990 | DEBUG    | nl2sql.agents.utils:execute_sql_query:88 - Returns rows: True
# 2025-07-08 05:10:47.992 | DEBUG    | nl2sql.agents.utils:execute_sql_query:95 - ✅ Query executed successfully. Returned 74 rows.
# 2025-07-08 05:10:47.993 | DEBUG    | __main__:sql_executor:260 - ✅ SQL execution status: success
# 2025-07-08 05:10:47.993 | DEBUG    | __main__:sql_executor:261 - ✅ SQL result: [{'product_category_name': 'cama_mesa_banho', 'order_count': 11115}, {'product_category_name': 'beleza_saude', 'order_count': 9670}, {'product_category_name': 'esporte_lazer', 'order_count': 8641}, {'product_category_name': 'moveis_decoracao', 'order_count': 8334}, {'product_category_name': 'informatica_acessorios', 'order_count': 7827}, {'product_category_name': 'utilidades_domesticas', 'order_count': 6964}, {'product_category_name': 'relogios_presentes', 'order_count': 5991}, {'product_category_name': 'telefonia', 'order_count': 4545}, {'product_category_name': 'ferramentas_jardim', 'order_count': 4347}, {'product_category_name': 'automotivo', 'order_count': 4235}, {'product_category_name': 'brinquedos', 'order_count': 4117}, {'product_category_name': 'cool_stuff', 'order_count': 3796}, {'product_category_name': 'perfumaria', 'order_count': 3419}, {'product_category_name': 'bebes', 'order_count': 3065}, {'product_category_name': 'eletronicos', 'order_count': 2767}, {'product_category_name': 'papelaria', 'order_count': 2517}, {'product_category_name': 'fashion_bolsas_e_acessorios', 'order_count': 2031}, {'product_category_name': 'pet_shop', 'order_count': 1947}, {'product_category_name': 'moveis_escritorio', 'order_count': 1691}, {'product_category_name': None, 'order_count': 1603}, {'product_category_name': 'consoles_games', 'order_count': 1137}, {'product_category_name': 'malas_acessorios', 'order_count': 1092}, {'product_category_name': 'construcao_ferramentas_construcao', 'order_count': 929}, {'product_category_name': 'eletrodomesticos', 'order_count': 771}, {'product_category_name': 'instrumentos_musicais', 'order_count': 680}, {'product_category_name': 'eletroportateis', 'order_count': 679}, {'product_category_name': 'casa_construcao', 'order_count': 604}, {'product_category_name': 'livros_interesse_geral', 'order_count': 553}, {'product_category_name': 'alimentos', 'order_count': 510}, {'product_category_name': 'moveis_sala', 'order_count': 503}, {'product_category_name': 'casa_conforto', 'order_count': 434}, {'product_category_name': 'bebidas', 'order_count': 379}, {'product_category_name': 'audio', 'order_count': 364}, {'product_category_name': 'market_place', 'order_count': 311}, {'product_category_name': 'construcao_ferramentas_iluminacao', 'order_count': 304}, {'product_category_name': 'climatizacao', 'order_count': 297}, {'product_category_name': 'moveis_cozinha_area_de_servico_jantar_e_jardim', 'order_count': 281}, {'product_category_name': 'alimentos_bebidas', 'order_count': 278}, {'product_category_name': 'industria_comercio_e_negocios', 'order_count': 268}, {'product_category_name': 'livros_tecnicos', 'order_count': 267}, {'product_category_name': 'telefonia_fixa', 'order_count': 264}, {'product_category_name': 'fashion_calcados', 'order_count': 262}, {'product_category_name': 'construcao_ferramentas_jardim', 'order_count': 238}, {'product_category_name': 'eletrodomesticos_2', 'order_count': 238}, {'product_category_name': 'agro_industria_e_comercio', 'order_count': 212}, {'product_category_name': 'artes', 'order_count': 209}, {'product_category_name': 'pcs', 'order_count': 203}, {'product_category_name': 'sinalizacao_e_seguranca', 'order_count': 199}, {'product_category_name': 'construcao_ferramentas_seguranca', 'order_count': 194}, {'product_category_name': 'artigos_de_natal', 'order_count': 153}]...
# 2025-07-08 05:10:47.994 | DEBUG    | __main__:check_sql_execution:359 - → Routing to success
# 2025-07-08 05:10:47.994 | INFO     | __main__:sql_result_analyzer:274 - 🔄 [Node] SQL Result Analyser
# 2025-07-08 05:10:56.333 | INFO     | __main__:sql_result_analyzer:308 - ✅ Results analyzed successfully
# {'messages': [HumanMessage(content='What are the most popular product categories?', additional_kwargs={}, response_metadata={}, id='03413633-c13c-4418-9a01-82fc7b5e370f'),
#   AIMessage(content='**SQL:**\n```sql\nSELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ecommerce"."products" p ON oi."product_id" = p."product_id" GROUP BY p."product_category_name" ORDER BY order_count DESC;\n```\n\n**Explanation:**\nThis query counts the number of order items for each product category to determine the most popular product categories, ordering the results by the count in descending order.\nShould I execute this query? Answer with \'yes\' or \'no\'.', additional_kwargs={}, response_metadata={}, id='7b5b843d-42de-401d-ab41-9fd1f2092d92'),
#   HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='cee58282-c931-45b4-a547-9115d39eb005'),
#   AIMessage(content='### Interpretation of Results: Most Popular Product Categories\n\n**Top 5 Product Categories by Order Volume:**\n1. **cama_mesa_banho** (Bed, Bath & Table) – **11,115 orders**\n2. **beleza_saude** (Beauty & Health) – **9,670 orders**\n3. **esporte_lazer** (Sports & Leisure) – **8,641 orders**\n4. **moveis_decoracao** (Furniture & Decoration) – **8,334 orders**\n5. **informatica_acessorios** (Computing Accessories) – **7,827 orders**\n\n#### Business Context & Insights\n\n- **Home & Living Dominates:** The leading category, *cama_mesa_banho*, indicates strong demand for home goods. This suggests that Olist’s customer base is highly engaged in home improvement and comfort-related purchases.\n- **Health & Beauty is a Key Segment:** *beleza_saude* ranks second, highlighting the importance of personal care and wellness products in the marketplace.\n- **Active Lifestyle Appeal:** *esporte_lazer*’s high ranking shows a significant interest in sports and leisure, which could be seasonal or reflect a broader lifestyle trend.\n- **Home Decor & Tech Accessories:** *moveis_decoracao* and *informatica_acessorios* round out the top five, showing that both home aesthetics and technology are important drivers of sales.\n\n#### Key Patterns & Trends\n\n- **Diverse Demand:** The top categories span home, personal care, leisure, and technology, indicating a well-diversified product demand across the platform.\n- **Potential for Cross-Selling:** Customers interested in home goods may also be receptive to related categories like furniture, decoration, and even electronics.\n- **Seasonality & Promotions:** Categories like sports/leisure and home goods may be influenced by seasonal trends (e.g., holidays, summer), suggesting opportunities for targeted promotions.\n\n#### Actionable Insights\n\n1. **Inventory & Supplier Focus:** Ensure robust inventory and strong supplier relationships in the top categories to meet demand and avoid stockouts.\n2. **Marketing Strategy:** Prioritize marketing spend and promotional campaigns around these high-performing categories, especially during peak seasons.\n3. **Cross-Selling Opportunities:** Develop bundles or recommendations that link top categories (e.g., home decor with bed & bath, or tech accessories with home office furniture).\n4. **Category Expansion:** Consider expanding the assortment within these leading categories or introducing complementary products to capture more wallet share.\n\n#### Next Steps\n\n- **Deeper Analysis:** Analyze customer demographics and purchase patterns within these categories to tailor marketing and product selection.\n- **Monitor Trends:** Regularly review category performance to identify emerging trends or shifts in consumer preferences.\n\n**Summary:**  \nThe Olist marketplace is driven by strong demand in home, health, leisure, and technology categories. Focusing on these areas can maximize sales, improve customer satisfaction, and inform strategic business decisions.', additional_kwargs={}, response_metadata={}, id='fa2aa221-ff30-4c35-8ecd-84d10c8f9099')],
#  'user_query': 'What are the most popular product categories?',
#  'user_intent': 'sql',
#  'sql_query': 'SELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ecommerce"."products" p ON oi."product_id" = p."product_id" GROUP BY p."product_category_name" ORDER BY order_count DESC;',
#  'sql_explanation': 'This query counts the number of order items for each product category to determine the most popular product categories, ordering the results by the count in descending order.',
#  'sql_execution_result': {'success': True,
#   'data': [{'product_category_name': 'cama_mesa_banho', 'order_count': 11115},
#    {'product_category_name': 'beleza_saude', 'order_count': 9670},
#    {'product_category_name': 'esporte_lazer', 'order_count': 8641},
#    {'product_category_name': 'moveis_decoracao', 'order_count': 8334},
#    {'product_category_name': 'informatica_acessorios', 'order_count': 7827},
#    {'product_category_name': 'utilidades_domesticas', 'order_count': 6964},
#    {'product_category_name': 'relogios_presentes', 'order_count': 5991},
#    {'product_category_name': 'telefonia', 'order_count': 4545},
#    {'product_category_name': 'ferramentas_jardim', 'order_count': 4347},
#    {'product_category_name': 'automotivo', 'order_count': 4235},
#    {'product_category_name': 'brinquedos', 'order_count': 4117},
#    {'product_category_name': 'cool_stuff', 'order_count': 3796},
#    {'product_category_name': 'perfumaria', 'order_count': 3419},
#    {'product_category_name': 'bebes', 'order_count': 3065},
#    {'product_category_name': 'eletronicos', 'order_count': 2767},
#    {'product_category_name': 'papelaria', 'order_count': 2517},
#    {'product_category_name': 'fashion_bolsas_e_acessorios',
#     'order_count': 2031},
#    {'product_category_name': 'pet_shop', 'order_count': 1947},
#    {'product_category_name': 'moveis_escritorio', 'order_count': 1691},
#    {'product_category_name': None, 'order_count': 1603},
#    {'product_category_name': 'consoles_games', 'order_count': 1137},
#    {'product_category_name': 'malas_acessorios', 'order_count': 1092},
#    {'product_category_name': 'construcao_ferramentas_construcao',
#     'order_count': 929},
#    {'product_category_name': 'eletrodomesticos', 'order_count': 771},
#    {'product_category_name': 'instrumentos_musicais', 'order_count': 680},
#    {'product_category_name': 'eletroportateis', 'order_count': 679},
#    {'product_category_name': 'casa_construcao', 'order_count': 604},
#    {'product_category_name': 'livros_interesse_geral', 'order_count': 553},
#    {'product_category_name': 'alimentos', 'order_count': 510},
#    {'product_category_name': 'moveis_sala', 'order_count': 503},
#    {'product_category_name': 'casa_conforto', 'order_count': 434},
#    {'product_category_name': 'bebidas', 'order_count': 379},
#    {'product_category_name': 'audio', 'order_count': 364},
#    {'product_category_name': 'market_place', 'order_count': 311},
#    {'product_category_name': 'construcao_ferramentas_iluminacao',
#     'order_count': 304},
#    {'product_category_name': 'climatizacao', 'order_count': 297},
#    {'product_category_name': 'moveis_cozinha_area_de_servico_jantar_e_jardim',
#     'order_count': 281},
#    {'product_category_name': 'alimentos_bebidas', 'order_count': 278},
#    {'product_category_name': 'industria_comercio_e_negocios',
#     'order_count': 268},
#    {'product_category_name': 'livros_tecnicos', 'order_count': 267},
#    {'product_category_name': 'telefonia_fixa', 'order_count': 264},
#    {'product_category_name': 'fashion_calcados', 'order_count': 262},
#    {'product_category_name': 'construcao_ferramentas_jardim',
#     'order_count': 238},
#    {'product_category_name': 'eletrodomesticos_2', 'order_count': 238},
#    {'product_category_name': 'agro_industria_e_comercio', 'order_count': 212},
#    {'product_category_name': 'artes', 'order_count': 209},
#    {'product_category_name': 'pcs', 'order_count': 203},
#    {'product_category_name': 'sinalizacao_e_seguranca', 'order_count': 199},
#    {'product_category_name': 'construcao_ferramentas_seguranca',
#     'order_count': 194},
#    {'product_category_name': 'artigos_de_natal', 'order_count': 153},
#    {'product_category_name': 'fashion_roupa_masculina', 'order_count': 132},
#    {'product_category_name': 'fashion_underwear_e_moda_praia',
#     'order_count': 131},
#    {'product_category_name': 'moveis_quarto', 'order_count': 109},
#    {'product_category_name': 'construcao_ferramentas_ferramentas',
#     'order_count': 103},
#    {'product_category_name': 'tablets_impressao_imagem', 'order_count': 83},
#    {'product_category_name': 'portateis_casa_forno_e_cafe', 'order_count': 76},
#    {'product_category_name': 'cine_foto', 'order_count': 72},
#    {'product_category_name': 'dvds_blu_ray', 'order_count': 64},
#    {'product_category_name': 'livros_importados', 'order_count': 60},
#    {'product_category_name': 'fashion_roupa_feminina', 'order_count': 48},
#    {'product_category_name': 'artigos_de_festas', 'order_count': 43},
#    {'product_category_name': 'fraldas_higiene', 'order_count': 39},
#    {'product_category_name': 'musica', 'order_count': 38},
#    {'product_category_name': 'moveis_colchao_e_estofado', 'order_count': 38},
#    {'product_category_name': 'flores', 'order_count': 33},
#    {'product_category_name': 'casa_conforto_2', 'order_count': 30},
#    {'product_category_name': 'fashion_esporte', 'order_count': 30},
#    {'product_category_name': 'artes_e_artesanato', 'order_count': 24},
#    {'product_category_name': 'portateis_cozinha_e_preparadores_de_alimentos',
#     'order_count': 15},
#    {'product_category_name': 'cds_dvds_musicais', 'order_count': 14},
#    {'product_category_name': 'la_cuisine', 'order_count': 14},
#    {'product_category_name': 'pc_gamer', 'order_count': 9},
#    {'product_category_name': 'fashion_roupa_infanto_juvenil',
#     'order_count': 8},
#    {'product_category_name': 'seguros_e_servicos', 'order_count': 2}],
#   'row_count': 74,
#   'error': None,
#   'query_executed': 'SELECT p."product_category_name", COUNT(*) AS order_count FROM "ecommerce"."order_items" oi JOIN "ecommerce"."products" p ON oi."product_id" = p."product_id" GROUP BY p."product_category_name" ORDER BY order_count DESC;'},
#  'sql_execution_analysis': '### Interpretation of Results: Most Popular Product Categories\n\n**Top 5 Product Categories by Order Volume:**\n1. **cama_mesa_banho** (Bed, Bath & Table) – **11,115 orders**\n2. **beleza_saude** (Beauty & Health) – **9,670 orders**\n3. **esporte_lazer** (Sports & Leisure) – **8,641 orders**\n4. **moveis_decoracao** (Furniture & Decoration) – **8,334 orders**\n5. **informatica_acessorios** (Computing Accessories) – **7,827 orders**\n\n#### Business Context & Insights\n\n- **Home & Living Dominates:** The leading category, *cama_mesa_banho*, indicates strong demand for home goods. This suggests that Olist’s customer base is highly engaged in home improvement and comfort-related purchases.\n- **Health & Beauty is a Key Segment:** *beleza_saude* ranks second, highlighting the importance of personal care and wellness products in the marketplace.\n- **Active Lifestyle Appeal:** *esporte_lazer*’s high ranking shows a significant interest in sports and leisure, which could be seasonal or reflect a broader lifestyle trend.\n- **Home Decor & Tech Accessories:** *moveis_decoracao* and *informatica_acessorios* round out the top five, showing that both home aesthetics and technology are important drivers of sales.\n\n#### Key Patterns & Trends\n\n- **Diverse Demand:** The top categories span home, personal care, leisure, and technology, indicating a well-diversified product demand across the platform.\n- **Potential for Cross-Selling:** Customers interested in home goods may also be receptive to related categories like furniture, decoration, and even electronics.\n- **Seasonality & Promotions:** Categories like sports/leisure and home goods may be influenced by seasonal trends (e.g., holidays, summer), suggesting opportunities for targeted promotions.\n\n#### Actionable Insights\n\n1. **Inventory & Supplier Focus:** Ensure robust inventory and strong supplier relationships in the top categories to meet demand and avoid stockouts.\n2. **Marketing Strategy:** Prioritize marketing spend and promotional campaigns around these high-performing categories, especially during peak seasons.\n3. **Cross-Selling Opportunities:** Develop bundles or recommendations that link top categories (e.g., home decor with bed & bath, or tech accessories with home office furniture).\n4. **Category Expansion:** Consider expanding the assortment within these leading categories or introducing complementary products to capture more wallet share.\n\n#### Next Steps\n\n- **Deeper Analysis:** Analyze customer demographics and purchase patterns within these categories to tailor marketing and product selection.\n- **Monitor Trends:** Regularly review category performance to identify emerging trends or shifts in consumer preferences.\n\n**Summary:**  \nThe Olist marketplace is driven by strong demand in home, health, leisure, and technology categories. Focusing on these areas can maximize sales, improve customer satisfaction, and inform strategic business decisions.',
#  'sql_safety_status': 'safe',
#  'sql_syntax_status': 'valid',
#  'user_feedback_status': 'approved',
#  'sql_execution_status': 'success'}
